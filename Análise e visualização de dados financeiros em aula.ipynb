# %%
# !pip install yahoo-finance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 2.4 MB/s eta 0:00:00
# ...
#   Created wheel for yahoo-finance: filename=yahoo_finance-1.4.0-py3-none-any.whl size=7230 sha256=73640ede5c604ae3b84ab36dd655c66c9e8b249bdba7aa859b6d2cc532e7d220
#   Stored in directory: /root/.cache/pip/wheels/f6/a9/34/f1aaa343d0861148f79a9df08f380e4dbbdbe27b7ba1e0e84c
# Successfully built yahoo-finance
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
petrobras = yf.download('PETR4.SA', start = '2018-01-01', end = '2023-04-26', actions = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petrobras
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02  16.190001  16.549999  16.190001  16.549999   7.292883  33461800
# 2018-01-03  16.490000  16.719999  16.370001  16.700001   7.358981  55940900
# 2018-01-04  16.780001  16.959999  16.620001  16.730000   7.372199  37064900
# 2018-01-05  16.700001  16.860001  16.570000  16.830000   7.416265  26958200
# 2018-01-08  16.740000  17.030001  16.709999  17.030001   7.504398  28400000
# ...               ...        ...        ...        ...        ...       ...
# 2023-04-18  26.709999  27.620001  26.520000  27.389999  27.389999  99478800
# 2023-04-19  27.160000  27.309999  26.450001  26.510000  26.510000  73217800
# 2023-04-20  26.520000  26.980000  26.290001  26.690001  26.690001  54738400
# 2023-04-24  26.600000  27.260000  26.500000  27.200001  27.200001  43820900
# 2023-04-25  27.160000  27.500000  26.719999  27.090000  27.090000  53854100
#
#             Dividends  Stock Splits
# Date
# ...

# %%
petrobras.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02  16.190001  16.549999  16.190001  16.549999   7.292883  33461800
# 2018-01-03  16.490000  16.719999  16.370001  16.700001   7.358981  55940900
# 2018-01-04  16.780001  16.959999  16.620001  16.730000   7.372199  37064900
# 2018-01-05  16.700001  16.860001  16.570000  16.830000   7.416265  26958200
# 2018-01-08  16.740000  17.030001  16.709999  17.030001   7.504398  28400000
#
#             Dividends  Stock Splits
# Date
# 2018-01-02        0.0           0.0
# 2018-01-03        0.0           0.0
# 2018-01-04        0.0           0.0
# 2018-01-05        0.0           0.0
# 2018-01-08        0.0           0.0

# %%
petrobras.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2023-04-18  26.709999  27.620001  26.520000  27.389999  27.389999  99478800
# 2023-04-19  27.160000  27.309999  26.450001  26.510000  26.510000  73217800
# 2023-04-20  26.520000  26.980000  26.290001  26.690001  26.690001  54738400
# 2023-04-24  26.600000  27.260000  26.500000  27.200001  27.200001  43820900
# 2023-04-25  27.160000  27.500000  26.719999  27.090000  27.090000  53854100
#
#             Dividends  Stock Splits
# Date
# 2023-04-18        0.0           0.0
# 2023-04-19        0.0           0.0
# 2023-04-20        0.0           0.0
# 2023-04-24        0.0           0.0
# 2023-04-25        0.0           0.0

# %%
acoes = ['PETR4.SA', 'ITUB4.SA', 'ITSA3.SA', 'MGLU3.SA', 'WEGE3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()

# %%
for acao in acoes:
  acoes_df[acao] = yf.download(acao, start = '2018-01-01', end = '2023-04-26', actions = False)['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#              PETR4.SA   ITUB4.SA  ITSA3.SA  MGLU3.SA   WEGE3.SA   BOVA11.SA
# Date
# 2018-01-02  16.549999  29.253332  8.516918  2.478125   9.623076   75.099998
# 2018-01-03  16.700001  29.453333  8.485777  2.446875   9.476923   75.300003
# 2018-01-04  16.730000  30.066666  8.680405  2.505625   9.384615   76.000000
# 2018-01-05  16.830000  30.153334  8.680405  2.456250   9.423076   76.440002
# 2018-01-08  17.030001  30.053333  8.773827  2.456562   9.500000   76.760002
# ...               ...        ...       ...       ...        ...         ...
# 2023-04-18  27.389999  25.940001  8.710000  3.540000  39.270000  102.699997
# 2023-04-19  26.510000  25.530001  8.680000  3.250000  39.110001  100.480003
# 2023-04-20  26.690001  25.600000  8.620000  3.300000  40.250000  101.000000
# 2023-04-24  27.200001  25.370001  8.700000  3.390000  40.349998  100.620003
# 2023-04-25  27.090000  25.600000  8.690000  3.280000  40.540001   99.919998
#
# [1317 rows x 6 columns]

# %%
acoes_df.head()
# Out:
#              PETR4.SA   ITUB4.SA  ITSA3.SA  MGLU3.SA  WEGE3.SA  BOVA11.SA
# Date
# 2018-01-02  16.549999  29.253332  8.516918  2.478125  9.623076  75.099998
# 2018-01-03  16.700001  29.453333  8.485777  2.446875  9.476923  75.300003
# 2018-01-04  16.730000  30.066666  8.680405  2.505625  9.384615  76.000000
# 2018-01-05  16.830000  30.153334  8.680405  2.456250  9.423076  76.440002
# 2018-01-08  17.030001  30.053333  8.773827  2.456562  9.500000  76.760002

# %%
acoes_df.tail()
# Out:
#              PETR4.SA   ITUB4.SA  ITSA3.SA  MGLU3.SA   WEGE3.SA   BOVA11.SA
# Date
# 2023-04-18  27.389999  25.940001      8.71      3.54  39.270000  102.699997
# 2023-04-19  26.510000  25.530001      8.68      3.25  39.110001  100.480003
# 2023-04-20  26.690001  25.600000      8.62      3.30  40.250000  101.000000
# 2023-04-24  27.200001  25.370001      8.70      3.39  40.349998  100.620003
# 2023-04-25  27.090000  25.600000      8.69      3.28  40.540001   99.919998

# %%
acoes_df.isnull().sum()
# Out:
# PETR4.SA      0
# ITUB4.SA      0
# ITSA3.SA      0
# MGLU3.SA      0
# WEGE3.SA      0
# BOVA11.SA    18
# dtype: int64

# %%
acoes_df.dropna(inplace = True)

# %%
acoes_df.isnull().sum()
# Out:
# PETR4.SA     0
# ITUB4.SA     0
# ITSA3.SA     0
# MGLU3.SA     0
# WEGE3.SA     0
# BOVA11.SA    0
# dtype: int64

# %%
acoes_df.columns
# Out:
# Index(['PETR4.SA', 'ITUB4.SA', 'ITSA3.SA', 'MGLU3.SA', 'WEGE3.SA',
#        'BOVA11.SA'],
#       dtype='object')

# %%
acoes_df.to_csv('acoes.csv')

# %%
acoes_df = pd.read_csv('/content/acoes.csv')

# %%
acoes_df
# Out:
#             Date   PETR4.SA   ITUB4.SA  ITSA3.SA  MGLU3.SA   WEGE3.SA  \
# 0     2018-01-02  16.549999  29.253332  8.516918  2.478125   9.623076
# 1     2018-01-03  16.700001  29.453333  8.485777  2.446875   9.476923
# 2     2018-01-04  16.730000  30.066666  8.680405  2.505625   9.384615
# 3     2018-01-05  16.830000  30.153334  8.680405  2.456250   9.423076
# 4     2018-01-08  17.030001  30.053333  8.773827  2.456562   9.500000
# ...          ...        ...        ...       ...       ...        ...
# 1294  2023-04-18  27.389999  25.940001  8.710000  3.540000  39.270000
# 1295  2023-04-19  26.510000  25.530001  8.680000  3.250000  39.110001
# 1296  2023-04-20  26.690001  25.600000  8.620000  3.300000  40.250000
# 1297  2023-04-24  27.200001  25.370001  8.700000  3.390000  40.349998
# 1298  2023-04-25  27.090000  25.600000  8.690000  3.280000  40.540001
#
#        BOVA11.SA
# 0      75.099998
# 1      75.300003
# 2      76.000000
# 3      76.440002
# 4      76.760002
# ...

# %%
acoes_df.columns[1:]
# Out:
# Index(['PETR4.SA', 'ITUB4.SA', 'ITSA3.SA', 'MGLU3.SA', 'WEGE3.SA',
#        'BOVA11.SA'],
#       dtype='object')

# %%
acoes_df.describe()
# Out:
#           PETR4.SA     ITUB4.SA     ITSA3.SA     MGLU3.SA     WEGE3.SA  \
# count  1299.000000  1299.000000  1299.000000  1299.000000  1299.000000
# mean     25.597537    29.098712     9.934256    10.164451    24.355731
# std       4.611322     4.540681     1.239990     7.466308    12.209926
# min      11.290000    20.520000     7.772727     2.130000     7.605000
# 25%      22.585000    25.309999     8.930735     4.053125     9.819038
# 50%      26.240000    28.500000     9.704840     6.480000    26.660000
# 75%      28.720000    33.410000    10.777252    15.750000    35.650002
# max      37.720001    39.689999    14.346320    27.450001    46.105000
#
#          BOVA11.SA
# count  1299.000000
# mean     98.233149
# std      13.517449
# min      61.139999
# 25%      90.334999
# 50%     100.099998
# 75%     108.405003
# max     125.750000

# %% [markdown]
# # Criando gráficos

# %%
sns.histplot(acoes_df['PETR4.SA'], bins=10);

# %%
len(acoes_df.columns)
# Out:
# 7

# %%
plt.figure(figsize=(10,50))

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i+1)
  sns.histplot(acoes_df[acoes_df.columns[i]], kde = True)
  plt.title(acoes_df.columns[i])

# %%
acoes_df['BOVA11.SA'].describe()
# Out:
# count    1299.000000
# mean       98.233149
# std        13.517449
# min        61.139999
# 25%        90.334999
# 50%       100.099998
# 75%       108.405003
# max       125.750000
# Name: BOVA11.SA, dtype: float64

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i+1)
  sns.boxplot(x = acoes_df[acoes_df.columns[i]])
  plt.title(acoes_df.columns[i])

# %%
acoes_df.plot(x = 'Date', figsize = (15,7), title = 'Histórico do preço das ações');

# %%
acoes_df_normalizado = acoes_df.copy()

for i in acoes_df_normalizado.columns[1:]:
  acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]

# %%
acoes_df_normalizado
# Out:
#             Date  PETR4.SA  ITUB4.SA  ITSA3.SA  MGLU3.SA  WEGE3.SA  BOVA11.SA
# 0     2018-01-02  1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 1     2018-01-03  1.009064  1.006837  0.996344  0.987390  0.984812   1.002663
# 2     2018-01-04  1.010876  1.027803  1.019195  1.011097  0.975220   1.011984
# 3     2018-01-05  1.016918  1.030766  1.019195  0.991173  0.979217   1.017843
# 4     2018-01-08  1.029003  1.027347  1.030164  0.991299  0.987210   1.022104
# ...          ...       ...       ...       ...       ...       ...        ...
# 1294  2023-04-18  1.654985  0.886737  1.022670  1.428499  4.080816   1.367510
# 1295  2023-04-19  1.601813  0.872721  1.019148  1.311475  4.064189   1.337949
# 1296  2023-04-20  1.612689  0.875114  1.012103  1.331652  4.182654   1.344874
# 1297  2023-04-24  1.643505  0.867252  1.021496  1.367970  4.193046   1.339814
# 1298  2023-04-25  1.636858  0.875114  1.020322  1.323581  4.212790   1.330493
#
# [1299 rows x 7 columns]

# %%
acoes_df_normalizado.plot(x='Date', figsize = (15,7), 
                             title = 'Histórico do preço das ações normalizado');

# %%
figura = px.line(title='Histórico do preços das ações')
for i in acoes_df.columns[1:]:
  figura.add_scatter(x = acoes_df['Date'], y = acoes_df[i], name = i)
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figura = px.line(title='Histórico do preços das ações')
for i in acoes_df_normalizado.columns[1:]:
  figura.add_scatter(x = acoes_df_normalizado['Date'], y = acoes_df_normalizado[i], name = i)
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
